# %%
# %load_ext tensorboard.notebook

# %%
import datetime
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import os.path


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
print(tf.__version__)
# Out:
# 2.0.0-alpha0

# %%
# google collab version
#CSV_FILE_NAME = "usgs_gsvb_v2.csv"
# jupyter notebook version
CSV_FILE_NAME = "../csv/usgs_gsvb_v2.csv"
os.environ['CSV_FILE_NAME'] = CSV_FILE_NAME

# %%
# The current directory will be where this src file is located.
# Which is in the src dir of the project
dirpath = os.getcwd()
print("current directory is : " + dirpath)
# Out:
# current directory is : /home/davis/progs/tf-hackathon/src

# %%
root_path = os.path.dirname(dirpath)
print("parent directory is : " + root_path)
# Out:
# parent directory is : /home/davis/progs/tf-hackathon

# %%
logs_path = os.path.join(root_path,"logs")
print("logs directory is : " + logs_path)
# Out:
# logs directory is : /home/davis/progs/tf-hackathon/logs

# %%
LOG_DIR_NAME = logs_path
os.environ['LOG_DIR_NAME'] = LOG_DIR_NAME

# %%
# %%bash
# echo ${LOG_DIR_NAME}
# Out:
# /home/davis/progs/tf-hackathon/logs

# %%
# %%bash
# head ${CSV_FILE_NAME}
# Out:
# usgs,site_no,date,tidal_high,tidal_low,precipitation_inches,lat,long
# GSVB,33670001,2019-03-08,-6.7913385826771648,-6.7257217847769031,,36.735303,-76.011602
# GSVB,33670001,2019-03-19,-6.8569553805774275,-6.758530183727034,,36.735303,-76.011602
# GSVB,33670001,2019-02-21,1.9356955380577427,2.1325459317585302,,36.735303,-76.011602
# GSVB,33670001,2019-03-11,-6.66010498687664,-6.4304461942257216,,36.735303,-76.011602
# GSVB,33670001,2019-04-04,1.9028871391076114,2.0669291338582676,,36.735303,-76.011602
# GSVB,33670001,2019-02-14,1.7716535433070866,1.9356955380577427,,36.735303,-76.011602
# GSVB,33670001,2019-04-14,2.2309711286089238,2.39501312335958,,36.735303,-76.011602
# GSVB,33670001,2019-02-24,2.65748031496063,2.9527559055118111,,36.735303,-76.011602
# GSVB,33670001,2019-01-12,2.2965879265091864,2.39501312335958,,36.735303,-76.011602

# %%
# %%bash
# # this csv file has 9875 lines corresponding to records (plus one header row)
# wc -l ${CSV_FILE_NAME}
# Out:
# 9876 ../csv/usgs_gsvb_v2.csv

# %% [markdown]
# # Use generic python to read data into pandas dataframe

# %%
# try again, but this time lets omit any samples which have missing values
raw_dataset = pd.read_csv(CSV_FILE_NAME, 
                          header=0,
                          parse_dates=[2],
                          sep=",")

dataset = raw_dataset.copy()

# %% [markdown]
# ## In order to add default values for missing data, use the converters helper functions

# %%
# Create a function to look for nans in the dataframe
# call via nans(dataset)
nans = lambda df: df[df.isnull().any(axis=1)]

# %%
# This should show an empty set
nans(dataset)
# Out:
#       usgs    site_no       date  tidal_high  tidal_low  precipitation_inches  \
# 0     GSVB   33670001 2019-03-08   -6.791339  -6.725722                   NaN
# 1     GSVB   33670001 2019-03-19   -6.856955  -6.758530                   NaN
# 2     GSVB   33670001 2019-02-21    1.935696   2.132546                   NaN
# 3     GSVB   33670001 2019-03-11   -6.660105  -6.430446                   NaN
# 4     GSVB   33670001 2019-04-04    1.902887   2.066929                   NaN
# 5     GSVB   33670001 2019-02-14    1.771654   1.935696                   NaN
# 6     GSVB   33670001 2019-04-14    2.230971   2.395013                   NaN
# 7     GSVB   33670001 2019-02-24    2.657480   2.952756                   NaN
# 8     GSVB   33670001 2019-01-12    2.296588   2.395013                   NaN
# 9     GSVB   33670001 2019-02-07    2.034121   2.198163                   NaN
# 10    GSVB   33670001 2019-01-17    2.493438   2.591864                   NaN
# 11    GSVB   33670001 2019-02-27   -6.660105  -6.561680                   NaN
# 12    GSVB   33670001 2019-03-21   -6.791339  -6.594488                   NaN
# 13    GSVB   33670001 2019-02-06    1.870079   2.132546                   NaN
# 14    GSVB   33670001 2019-01-29    1.804462   2.001312                   NaN
# 15    GSVB   33670001 2019-03-18   -6.856955  -6.758530                   NaN
# 16    GSVB   33670001 2019-01-13    2.362205   2.887139                   NaN
# 17    GSVB   33670001 2019-03-23   -6.856955  -6.692913                   NaN
# 18    GSVB   33670001 2019-04-06    1.902887   2.001312                   NaN
# 19    GSVB   33670001 2019-01-30    1.804462   1.968504                   NaN
# 20    GSVB   33670001 2019-01-14    2.723097   2.887139                   NaN
# 21    GSVB   33670001 2019-01-04    2.526247   2.624672                   NaN
# 22    GSVB   33670001 2019-04-11    1.902887   2.001312                   NaN
# 23    GSVB   33670001 2019-03-09   -6.824147  -6.725722                   NaN
# 24    GSVB   33670001 2019-03-04   -6.692913  -6.496063                   NaN
# 25    GSVB   33670001 2019-03-20   -6.856955  -6.758530                   NaN
# 26    GSVB   33670001 2019-02-04    1.837270   1.935696                   NaN
# 27    GSVB   33670001 2019-03-07   -6.856955  -6.725722                   NaN
# 28    GSVB   33670001 2019-01-18    2.460630   2.559055                   NaN
# 29    GSVB   33670001 2019-02-09    1.706037   1.935696                   NaN
# ...    ...        ...        ...         ...        ...                   ...
# 5781  USGS  204291317 2016-05-15    1.320000  -0.850000                   NaN
# 5782  USGS  204291317 2016-05-30    1.530000  -1.190000                   NaN
# 5783  USGS  204291317 2018-11-14         NaN        NaN                   NaN
# 5784  USGS  204291317 2016-05-16    0.570000  -1.460000                   NaN
# 5785  USGS  204291317 2016-06-06    1.850000  -1.260000                   NaN
# 5786  USGS  204291317 2016-06-11    0.910000  -1.530000                   NaN
# 5787  USGS  204291317 2016-06-20    1.250000  -1.420000                   NaN
# 5788  USGS  204291317 2016-06-04    2.220000  -1.110000                   NaN
# 5789  USGS  204291317 2016-06-17    2.510000  -0.320000                   NaN
# 5790  USGS  204291317 2016-06-08    2.010000  -0.850000                   NaN
# 5791  USGS  204291317 2018-09-09         NaN        NaN                   NaN
# 5792  USGS  204291317 2016-05-29    1.020000  -1.290000                   NaN
# 5793  USGS  204291317 2016-06-18    1.670000  -0.460000                   NaN
# 5794  USGS  204291317 2016-05-28    0.900000  -1.250000                   NaN
# 5795  USGS  204291317 2016-05-27    0.810000  -1.450000                   NaN
# 5796  USGS  204291317 2016-06-05    2.150000  -1.300000                   NaN
# 5797  USGS  204291317 2018-11-04         NaN        NaN                   NaN
# 5798  USGS  204291317 2016-05-18    1.150000  -1.360000                   NaN
# 5799  USGS  204291317 2016-05-23    1.930000  -0.590000                   NaN
# 7648  USGS  204297575 2017-05-04         NaN        NaN                  0.00
# 7983  USGS  204288721 2018-06-30         NaN        NaN                  0.00
# 8416  USGS  204288721 2018-06-19         NaN        NaN                  0.00
# 9068  USGS  204291317 2017-06-08         NaN        NaN                  0.00
# 9112  USGS  204300267 2017-06-28         NaN   0.300000                  0.09
# 9116  USGS  204300267 2017-08-02         NaN   0.520000                  0.09
# 9263  USGS  204297575 2016-07-16         NaN        NaN                  0.01
# 9643  USGS  204300267 2017-02-19         NaN   0.320000                  0.08
# 9645  USGS  204300267 2017-06-10         NaN   0.800000                  0.08
# 9707  USGS  204300267 2017-02-24         NaN   0.270000                  0.05
# 9861  USGS  204300267 2017-05-13         NaN   0.370000                  0.06
#
#             lat       long
# 0     36.735303 -76.011602
# 1     36.735303 -76.011602
# 2     36.735303 -76.011602
# 3     36.735303 -76.011602
# 4     36.735303 -76.011602
# 5     36.735303 -76.011602
# 6     36.735303 -76.011602
# 7     36.735303 -76.011602
# 8     36.735303 -76.011602
# 9     36.735303 -76.011602
# 10    36.735303 -76.011602
# 11    36.735303 -76.011602
# 12    36.735303 -76.011602
# 13    36.735303 -76.011602
# 14    36.735303 -76.011602
# 15    36.735303 -76.011602
# 16    36.735303 -76.011602
# 17    36.735303 -76.011602
# 18    36.735303 -76.011602
# 19    36.735303 -76.011602
# 20    36.735303 -76.011602
# 21    36.735303 -76.011602
# 22    36.735303 -76.011602
# 23    36.735303 -76.011602
# 24    36.735303 -76.011602
# 25    36.735303 -76.011602
# 26    36.735303 -76.011602
# 27    36.735303 -76.011602
# 28    36.735303 -76.011602
# 29    36.735303 -76.011602
# ...         ...        ...
# 5781  36.843306 -76.124472
# 5782  36.843306 -76.124472
# 5783  36.843306 -76.124472
# 5784  36.843306 -76.124472
# 5785  36.843306 -76.124472
# 5786  36.843306 -76.124472
# 5787  36.843306 -76.124472
# 5788  36.843306 -76.124472
# 5789  36.843306 -76.124472
# 5790  36.843306 -76.124472
# 5791  36.843306 -76.124472
# 5792  36.843306 -76.124472
# 5793  36.843306 -76.124472
# 5794  36.843306 -76.124472
# 5795  36.843306 -76.124472
# 5796  36.843306 -76.124472
# 5797  36.843306 -76.124472
# 5798  36.843306 -76.124472
# 5799  36.843306 -76.124472
# 7648  36.824778 -75.985250
# 7983  36.827222 -76.165556
# 8416  36.827222 -76.165556
# 9068  36.843306 -76.124472
# 9112  36.679806 -75.984000
# 9116  36.679806 -75.984000
# 9263  36.824778 -75.985250
# 9643  36.679806 -75.984000
# 9645  36.679806 -75.984000
# 9707  36.679806 -75.984000
# 9861  36.679806 -75.984000
#
# [3903 rows x 8 columns]

# %%
dataset.dropna(inplace=True)
nans(dataset)
# Out:
# Empty DataFrame
# Columns: [usgs, site_no, date, tidal_high, tidal_low, precipitation_inches, lat, long]
# Index: []

# %%
dataset.shape
#dataset.head()
# Out:
# (5972, 8)

# %% [markdown]
# # Removing the NA's, removes all of the gsvb sensor readings

# %%
dataset[dataset.usgs == 'GSVB']
# Out:
# Empty DataFrame
# Columns: [usgs, site_no, date, tidal_high, tidal_low, precipitation_inches, lat, long]
# Index: []

# %%
# drop any columns which we will not use
dataset.drop(['usgs','tidal_low','site_no'], axis=1, inplace=True)
dataset.head()
# Out:
#           date  tidal_high  precipitation_inches        lat       long
# 851 2017-05-12        2.78                  0.95  36.841139 -76.057139
# 852 2017-07-14        1.07                  0.23  36.841139 -76.057139
# 853 2017-06-20        1.28                  0.23  36.841139 -76.057139
# 854 2018-03-11        0.66                  0.11  36.841139 -76.057139
# 855 2018-04-24        1.28                  0.48  36.841139 -76.057139

# %% [markdown]
# # Create new columns for year, month, day from the date column

# %%
def create_ymd_cols(df, column):
    df[column + "_year"] = df[column].apply(lambda x: x.year)
    df[column + "_month"] = df[column].apply(lambda x: x.month)
    df[column + "_day"] = df[column].apply(lambda x: x.day)
    
create_ymd_cols(dataset, 'date')

# %%
dataset.head()
# Out:
#           date  tidal_high  precipitation_inches        lat       long  \
# 851 2017-05-12        2.78                  0.95  36.841139 -76.057139
# 852 2017-07-14        1.07                  0.23  36.841139 -76.057139
# 853 2017-06-20        1.28                  0.23  36.841139 -76.057139
# 854 2018-03-11        0.66                  0.11  36.841139 -76.057139
# 855 2018-04-24        1.28                  0.48  36.841139 -76.057139
#
#      date_year  date_month  date_day
# 851       2017           5        12
# 852       2017           7        14
# 853       2017           6        20
# 854       2018           3        11
# 855       2018           4        24

# %%
# remove the date column
dataset.pop('date')
dataset.head()
# Out:
#      tidal_high  precipitation_inches        lat       long  date_year  \
# 851        2.78                  0.95  36.841139 -76.057139       2017
# 852        1.07                  0.23  36.841139 -76.057139       2017
# 853        1.28                  0.23  36.841139 -76.057139       2017
# 854        0.66                  0.11  36.841139 -76.057139       2018
# 855        1.28                  0.48  36.841139 -76.057139       2018
#
#      date_month  date_day
# 851           5        12
# 852           7        14
# 853           6        20
# 854           3        11
# 855           4        24

# %%
train_ds = dataset.sample(frac=0.7,random_state=3367)
leftover_ds = dataset.drop(train_ds.index)
test_ds = leftover_ds.sample(frac=0.5, random_state=3367)
valid_ds = leftover_ds.drop(test_ds.index)

# %%
# Create seperate series/dataframe? for labels
# Remove the label from the dataframes.
train_labels = train_ds.pop('tidal_high')
test_labels = test_ds.pop('tidal_high')
valid_labels = valid_ds.pop('tidal_high')

# %% [markdown]
# # Normalize the data

# %%
train_stats_df = train_ds.copy()
train_stats = train_stats_df.describe().transpose()

# %%
def norm(a_df):
    # Do the norm operation
    normed_df = (a_df - train_stats['mean']) / train_stats['std']
    return normed_df

normed_train_ds = norm(train_ds)
normed_test_ds = norm(test_ds)
normed_valid_ds = norm(valid_ds)

# %% [markdown]
# # Build the model again

# %%
# train_ds determines the input feature size
model = keras.Sequential([
    layers.Dense(64, activation=tf.nn.relu, input_shape=[len(normed_train_ds.keys())]),
    layers.Dense(64, activation=tf.nn.relu),
    layers.Dense(1)
    ])

optimizer = tf.keras.optimizers.RMSprop(0.001)

model.compile(loss='mean_squared_error',
              optimizer=optimizer,
              metrics=['mean_absolute_error', 'mean_squared_error'])

# %% [markdown]
# # Train the model again  (tensorboard version)

# %%
EPOCHS = 2000

# %%
# %%bash
# # clear any logs from previous runs
# rm -rf ${LOG_DIR_NAME}

# %%
logdir = os.path.join(LOG_DIR_NAME, datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
print(logdir)
# Out:
# /home/davis/progs/tf-hackathon/logs/20190506-162408

# %%
os.environ['LOG_DIR_NAME_TIME_VARIABLE'] = logdir

# %%
# cell magic is weird on how to evaluate this
# this works since its hard coded but not time variable
#%tensorboard --logdir '/home/davis/progs/tf-hackathon/logs'
# ps auxw | grep tensorboard show this as literal --logdir logdir
#%tensorboard --logdir logdir
# ps auxw | grep tensorboard show this as literal --logdir $/home/davis/....
#%tensorboard --logdir ${LOG_DIR_NAME}
# ps auxw | grep tensorboard show this as literal --logdir /home/davis/...
# this works because it finds tf events in root down
#%tensorboard --logdir {LOG_DIR_NAME}
# this does not work.  ps auxw shows tensorboard --logdir {LOG_DIR_NAME_TIME_VARIABLE}
#%tensorboard --logdir {LOG_DIR_NAME_TIME_VARIABLE}
# this works best. it shows up in tensorboard with time variable. tensorboard --logdir /home/davis/progs/tf-hackathon/logs/20190506-115136
# %tensorboard --logdir {logdir}
# Out:
# Reusing TensorBoard on port 6013 (pid 28713), started -1 day, 23:06:59 ago. (Use '!kill 28713' to kill it.)
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:6013"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
history = model.fit(normed_train_ds, 
                    train_labels,
                    epochs=EPOCHS, 
                    validation_split = 0.2, 
                    verbose=0,
                    callbacks=[tensorboard_callback])

# %% [markdown]
# # Train the model again (history plots) version

# %%
# %%bash
# # clear any logs from previous runs
# pwd
# rm -rf ./${LOG_DIR_NAME}

# %%
# Display training progress by printing a single dot for each completed epoch
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

# %%
# The author is printing dots rather than the regular output. Interesting.
# Also, the author is saving the result of model.fit and then loads the history portion
# into a dataframe later
EPOCHS = 1000

history = model.fit(normed_train_ds, 
                    train_labels,
                    epochs=EPOCHS, 
                    validation_split = 0.2, 
                    verbose=0,
                    callbacks=[PrintDot()])

# %%
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch


    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Epoch Loss [Tidal_high]')
    plt.plot(hist['epoch'], hist['loss'],label='Train Loss')
    plt.plot(hist['epoch'], hist['val_loss'],label = 'Val Loss')
    plt.ylim([0,1.5])
    plt.legend()


    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error [Tidal_high]')
    plt.plot(hist['epoch'], hist['mean_absolute_error'],label='Train Error')
    plt.plot(hist['epoch'], hist['val_mean_absolute_error'],label = 'Val Error')
    plt.ylim([0,1])
    plt.legend()

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Square Error [$Tidal_high^2$]')
    plt.plot(hist['epoch'], hist['mean_squared_error'],label='Train Error')
    plt.plot(hist['epoch'], hist['val_mean_squared_error'],label = 'Val Error')
    plt.ylim([0,2])
    plt.legend()
    plt.show()


plot_history(history)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

# %%
hist

# %% [markdown]
# After the lat,long are normalized it still does not show improvement on the validation set.  Instead of using the training data for training and a hold out amount on the validation, lets use the original splits which are shuffled.
